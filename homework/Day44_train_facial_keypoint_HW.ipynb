# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# C:\Users\a2541\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\a2541\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\a2541\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\a2541\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 2s 1ms/step - loss: 0.0061 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00235, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00235 to 0.00194, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00194 to 0.00183, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00183
# Epoch 5/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00005: val_loss improved from 0.00183 to 0.00174, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 8.5887e-04 - val_loss: 0.0015
#
# Epoch 00006: val_loss improved from 0.00174 to 0.00153, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 7.0397e-04 - val_loss: 0.0014
#
# Epoch 00007: val_loss improved from 0.00153 to 0.00135, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 6.2664e-04 - val_loss: 0.0013
#
# Epoch 00008: val_loss improved from 0.00135 to 0.00135, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 5.5074e-04 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00135 to 0.00116, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 4.9719e-04 - val_loss: 0.0011
#
# Epoch 00010: val_loss improved from 0.00116 to 0.00106, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 4.6922e-04 - val_loss: 9.9521e-04
#
# Epoch 00011: val_loss improved from 0.00106 to 0.00100, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 4.3178e-04 - val_loss: 9.4068e-04
#
# Epoch 00012: val_loss improved from 0.00100 to 0.00094, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 4.0814e-04 - val_loss: 9.2782e-04
#
# Epoch 00013: val_loss improved from 0.00094 to 0.00093, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 3.8894e-04 - val_loss: 8.8221e-04
#
# Epoch 00014: val_loss improved from 0.00093 to 0.00088, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 3.7327e-04 - val_loss: 9.1547e-04
#
# Epoch 00015: val_loss did not improve from 0.00088
# Epoch 16/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 3.5581e-04 - val_loss: 8.4685e-04
#
# Epoch 00016: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 3.2961e-04 - val_loss: 8.1494e-04
#
# Epoch 00017: val_loss improved from 0.00085 to 0.00081, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 3.2701e-04 - val_loss: 8.4021e-04
#
# Epoch 00018: val_loss did not improve from 0.00081
# Epoch 19/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 3.1337e-04 - val_loss: 8.0795e-04
#
# Epoch 00019: val_loss improved from 0.00081 to 0.00081, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 3.0851e-04 - val_loss: 7.8807e-04
#
# Epoch 00020: val_loss improved from 0.00081 to 0.00079, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 2.9070e-04 - val_loss: 7.9999e-04
#
# Epoch 00021: val_loss did not improve from 0.00079
# Epoch 22/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 2.8310e-04 - val_loss: 8.0933e-04
#
# Epoch 00022: val_loss did not improve from 0.00079
# Epoch 23/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.8652e-04 - val_loss: 7.9700e-04
#
# Epoch 00023: val_loss did not improve from 0.00079
# Epoch 24/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.7220e-04 - val_loss: 7.6790e-04
#
# Epoch 00024: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.6378e-04 - val_loss: 8.0715e-04
#
# Epoch 00025: val_loss did not improve from 0.00077
# Epoch 26/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.6047e-04 - val_loss: 7.7557e-04
#
# Epoch 00026: val_loss did not improve from 0.00077
# Epoch 27/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 2.5166e-04 - val_loss: 7.8870e-04
#
# Epoch 00027: val_loss did not improve from 0.00077
# Epoch 28/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 2.4888e-04 - val_loss: 7.7293e-04
#
# Epoch 00028: val_loss did not improve from 0.00077
# Epoch 29/150
# 1712/1712 [==============================] - 1s 465us/step - loss: 2.4121e-04 - val_loss: 7.6682e-04
#
# Epoch 00029: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 1s 469us/step - loss: 2.3878e-04 - val_loss: 8.1285e-04
#
# Epoch 00030: val_loss did not improve from 0.00077
# Epoch 31/150
# 1712/1712 [==============================] - 1s 467us/step - loss: 2.4007e-04 - val_loss: 7.3453e-04
#
# Epoch 00031: val_loss improved from 0.00077 to 0.00073, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 2.2831e-04 - val_loss: 7.4572e-04
#
# Epoch 00032: val_loss did not improve from 0.00073
# Epoch 33/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 2.2019e-04 - val_loss: 7.3833e-04
#
# Epoch 00033: val_loss did not improve from 0.00073
# Epoch 34/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 2.1791e-04 - val_loss: 7.9932e-04
#
# Epoch 00034: val_loss did not improve from 0.00073
# Epoch 35/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.2064e-04 - val_loss: 7.6070e-04
#
# Epoch 00035: val_loss did not improve from 0.00073
# Epoch 36/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 2.0826e-04 - val_loss: 7.1329e-04
#
# Epoch 00036: val_loss improved from 0.00073 to 0.00071, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 2.0907e-04 - val_loss: 7.4783e-04
#
# Epoch 00037: val_loss did not improve from 0.00071
# Epoch 38/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 2.0393e-04 - val_loss: 7.8827e-04
#
# Epoch 00038: val_loss did not improve from 0.00071
# Epoch 39/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 2.0639e-04 - val_loss: 7.7487e-04
#
# Epoch 00039: val_loss did not improve from 0.00071
# Epoch 40/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.9511e-04 - val_loss: 7.3541e-04
#
# Epoch 00040: val_loss did not improve from 0.00071
# Epoch 41/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.9790e-04 - val_loss: 7.4900e-04
#
# Epoch 00041: val_loss did not improve from 0.00071
# Epoch 42/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.9616e-04 - val_loss: 7.8642e-04
#
# Epoch 00042: val_loss did not improve from 0.00071
# Epoch 43/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.8892e-04 - val_loss: 7.0673e-04
#
# Epoch 00043: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.8826e-04 - val_loss: 7.1164e-04
#
# Epoch 00044: val_loss did not improve from 0.00071
# Epoch 45/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.8445e-04 - val_loss: 7.2329e-04
#
# Epoch 00045: val_loss did not improve from 0.00071
# Epoch 46/150
# 1712/1712 [==============================] - 1s 452us/step - loss: 1.8256e-04 - val_loss: 7.2071e-04
#
# Epoch 00046: val_loss did not improve from 0.00071
# Epoch 47/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.8580e-04 - val_loss: 7.3714e-04
#
# Epoch 00047: val_loss did not improve from 0.00071
# Epoch 48/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.7445e-04 - val_loss: 7.1750e-04
#
# Epoch 00048: val_loss did not improve from 0.00071
# Epoch 49/150
# 1712/1712 [==============================] - 1s 466us/step - loss: 1.7910e-04 - val_loss: 7.1551e-04
#
# Epoch 00049: val_loss did not improve from 0.00071
# Epoch 50/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.7277e-04 - val_loss: 7.1982e-04
#
# Epoch 00050: val_loss did not improve from 0.00071
# Epoch 51/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 1.7368e-04 - val_loss: 7.4920e-04
#
# Epoch 00051: val_loss did not improve from 0.00071
# Epoch 52/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.7100e-04 - val_loss: 7.3212e-04
#
# Epoch 00052: val_loss did not improve from 0.00071
# Epoch 53/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.7075e-04 - val_loss: 7.3655e-04
#
# Epoch 00053: val_loss did not improve from 0.00071
# Epoch 54/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.6504e-04 - val_loss: 7.5085e-04
#
# Epoch 00054: val_loss did not improve from 0.00071
# Epoch 55/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.6333e-04 - val_loss: 7.6153e-04
#
# Epoch 00055: val_loss did not improve from 0.00071
# Epoch 56/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.6575e-04 - val_loss: 6.9353e-04
#
# Epoch 00056: val_loss improved from 0.00071 to 0.00069, saving model to best_weights.h5
# Epoch 57/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.7095e-04 - val_loss: 7.2853e-04
#
# Epoch 00057: val_loss did not improve from 0.00069
# Epoch 58/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.6426e-04 - val_loss: 7.6624e-04
#
# Epoch 00058: val_loss did not improve from 0.00069
# Epoch 59/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.5990e-04 - val_loss: 7.4618e-04
#
# Epoch 00059: val_loss did not improve from 0.00069
# Epoch 60/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.5592e-04 - val_loss: 7.1598e-04
#
# Epoch 00060: val_loss did not improve from 0.00069
# Epoch 61/150
# 1712/1712 [==============================] - 1s 463us/step - loss: 1.6070e-04 - val_loss: 7.6015e-04
#
# Epoch 00061: val_loss did not improve from 0.00069
# Epoch 62/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.5769e-04 - val_loss: 6.9540e-04
#
# Epoch 00062: val_loss did not improve from 0.00069
# Epoch 63/150
# 1712/1712 [==============================] - 1s 478us/step - loss: 1.5047e-04 - val_loss: 7.2516e-04
#
# Epoch 00063: val_loss did not improve from 0.00069
# Epoch 64/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.4983e-04 - val_loss: 7.2496e-04
#
# Epoch 00064: val_loss did not improve from 0.00069
# Epoch 65/150
# 1712/1712 [==============================] - 1s 467us/step - loss: 1.4830e-04 - val_loss: 7.1448e-04
#
# Epoch 00065: val_loss did not improve from 0.00069
# Epoch 66/150
# 1712/1712 [==============================] - 1s 469us/step - loss: 1.4637e-04 - val_loss: 7.1460e-04
#
# Epoch 00066: val_loss did not improve from 0.00069
# Epoch 67/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.4863e-04 - val_loss: 7.2163e-04
#
# Epoch 00067: val_loss did not improve from 0.00069
# Epoch 68/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.4752e-04 - val_loss: 7.3897e-04
#
# Epoch 00068: val_loss did not improve from 0.00069
# Epoch 69/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.4901e-04 - val_loss: 6.9828e-04
#
# Epoch 00069: val_loss did not improve from 0.00069
# Epoch 70/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.5371e-04 - val_loss: 7.3129e-04
#
# Epoch 00070: val_loss did not improve from 0.00069
# Epoch 71/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.4613e-04 - val_loss: 7.1980e-04
#
# Epoch 00071: val_loss did not improve from 0.00069
# Epoch 72/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.4186e-04 - val_loss: 7.2443e-04
#
# Epoch 00072: val_loss did not improve from 0.00069
# Epoch 73/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.3742e-04 - val_loss: 7.2008e-04
#
# Epoch 00073: val_loss did not improve from 0.00069
# Epoch 74/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.3099e-04 - val_loss: 7.1040e-04
#
# Epoch 00074: val_loss did not improve from 0.00069
# Epoch 75/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3546e-04 - val_loss: 7.3529e-04
#
# Epoch 00075: val_loss did not improve from 0.00069
# Epoch 76/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.3413e-04 - val_loss: 7.2446e-04
#
# Epoch 00076: val_loss did not improve from 0.00069
# Epoch 77/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.3551e-04 - val_loss: 7.4961e-04
#
# Epoch 00077: val_loss did not improve from 0.00069
# Epoch 78/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.3340e-04 - val_loss: 7.3700e-04
#
# Epoch 00078: val_loss did not improve from 0.00069
# Epoch 79/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.3239e-04 - val_loss: 7.1634e-04
#
# Epoch 00079: val_loss did not improve from 0.00069
# Epoch 80/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.3729e-04 - val_loss: 7.4854e-04
#
# Epoch 00080: val_loss did not improve from 0.00069
# Epoch 81/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.2927e-04 - val_loss: 7.2449e-04
#
# Epoch 00081: val_loss did not improve from 0.00069
# Epoch 82/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.3006e-04 - val_loss: 7.6604e-04
#
# Epoch 00082: val_loss did not improve from 0.00069
# Epoch 83/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.2796e-04 - val_loss: 7.4572e-04
#
# Epoch 00083: val_loss did not improve from 0.00069
# Epoch 84/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 1.2722e-04 - val_loss: 7.2472e-04
#
# Epoch 00084: val_loss did not improve from 0.00069
# Epoch 85/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.2932e-04 - val_loss: 6.9720e-04
#
# Epoch 00085: val_loss did not improve from 0.00069
# Epoch 86/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 1.2534e-04 - val_loss: 7.2649e-04
#
# Epoch 00086: val_loss did not improve from 0.00069
# Epoch 87/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.2651e-04 - val_loss: 7.7714e-04
#
# Epoch 00087: val_loss did not improve from 0.00069
# Epoch 88/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2581e-04 - val_loss: 7.4344e-04
#
# Epoch 00088: val_loss did not improve from 0.00069
# Epoch 89/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.2128e-04 - val_loss: 7.3876e-04
#
# Epoch 00089: val_loss did not improve from 0.00069
# Epoch 90/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 1.1970e-04 - val_loss: 7.6719e-04
#
# Epoch 00090: val_loss did not improve from 0.00069
# Epoch 91/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.2000e-04 - val_loss: 7.4219e-04
#
# Epoch 00091: val_loss did not improve from 0.00069
# Epoch 92/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.1853e-04 - val_loss: 7.3590e-04
#
# Epoch 00092: val_loss did not improve from 0.00069
# Epoch 93/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.2607e-04 - val_loss: 7.7292e-04
#
# Epoch 00093: val_loss did not improve from 0.00069
# Epoch 94/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.1483e-04 - val_loss: 7.6063e-04
#
# Epoch 00094: val_loss did not improve from 0.00069
# Epoch 95/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1655e-04 - val_loss: 7.2043e-04
#
# Epoch 00095: val_loss did not improve from 0.00069
# Epoch 96/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.1506e-04 - val_loss: 7.1404e-04
#
# Epoch 00096: val_loss did not improve from 0.00069
# Epoch 97/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 1.2096e-04 - val_loss: 7.0573e-04
#
# Epoch 00097: val_loss did not improve from 0.00069
# Epoch 98/150
# 1712/1712 [==============================] - 1s 465us/step - loss: 1.1592e-04 - val_loss: 7.2796e-04
#
# Epoch 00098: val_loss did not improve from 0.00069
# Epoch 99/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1453e-04 - val_loss: 7.1626e-04
#
# Epoch 00099: val_loss did not improve from 0.00069
# Epoch 100/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.1244e-04 - val_loss: 7.0359e-04
#
# Epoch 00100: val_loss did not improve from 0.00069
# Epoch 101/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1180e-04 - val_loss: 7.4123e-04
#
# Epoch 00101: val_loss did not improve from 0.00069
# Epoch 102/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.1098e-04 - val_loss: 7.0449e-04
#
# Epoch 00102: val_loss did not improve from 0.00069
# Epoch 103/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.1096e-04 - val_loss: 7.5098e-04
#
# Epoch 00103: val_loss did not improve from 0.00069
# Epoch 104/150
# 1712/1712 [==============================] - 1s 465us/step - loss: 1.0864e-04 - val_loss: 7.0391e-04
#
# Epoch 00104: val_loss did not improve from 0.00069
# Epoch 105/150
# 1712/1712 [==============================] - 1s 468us/step - loss: 1.0993e-04 - val_loss: 7.3865e-04
#
# Epoch 00105: val_loss did not improve from 0.00069
# Epoch 106/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 1.0814e-04 - val_loss: 7.1588e-04
#
# Epoch 00106: val_loss did not improve from 0.00069
# Epoch 107/150
# 1712/1712 [==============================] - 1s 472us/step - loss: 1.1219e-04 - val_loss: 7.1108e-04
#
# Epoch 00107: val_loss did not improve from 0.00069
# Epoch 108/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.0799e-04 - val_loss: 7.1811e-04
#
# Epoch 00108: val_loss did not improve from 0.00069
# Epoch 109/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.0659e-04 - val_loss: 6.9841e-04
#
# Epoch 00109: val_loss did not improve from 0.00069
# Epoch 110/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 1.0883e-04 - val_loss: 7.1881e-04
#
# Epoch 00110: val_loss did not improve from 0.00069
# Epoch 111/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0560e-04 - val_loss: 7.4889e-04
#
# Epoch 00111: val_loss did not improve from 0.00069
# Epoch 112/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 1.0780e-04 - val_loss: 7.0811e-04
#
# Epoch 00112: val_loss did not improve from 0.00069
# Epoch 113/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 1.0923e-04 - val_loss: 7.4716e-04
#
# Epoch 00113: val_loss did not improve from 0.00069
# Epoch 114/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 1.0385e-04 - val_loss: 7.1781e-04
#
# Epoch 00114: val_loss did not improve from 0.00069
# Epoch 115/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 1.0235e-04 - val_loss: 7.4666e-04
#
# Epoch 00115: val_loss did not improve from 0.00069
# Epoch 116/150
# 1712/1712 [==============================] - 1s 465us/step - loss: 1.0106e-04 - val_loss: 7.1105e-04
#
# Epoch 00116: val_loss did not improve from 0.00069
# Epoch 117/150
# 1712/1712 [==============================] - 1s 465us/step - loss: 1.0109e-04 - val_loss: 7.5092e-04
#
# Epoch 00117: val_loss did not improve from 0.00069
# Epoch 118/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.9035e-05 - val_loss: 7.3419e-04
#
# Epoch 00118: val_loss did not improve from 0.00069
# Epoch 119/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 9.8989e-05 - val_loss: 7.1092e-04
#
# Epoch 00119: val_loss did not improve from 0.00069
# Epoch 120/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 9.9736e-05 - val_loss: 7.2906e-04
#
# Epoch 00120: val_loss did not improve from 0.00069
# Epoch 121/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 1.0068e-04 - val_loss: 7.2163e-04
#
# Epoch 00121: val_loss did not improve from 0.00069
# Epoch 122/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.9051e-05 - val_loss: 7.1115e-04
#
# Epoch 00122: val_loss did not improve from 0.00069
# Epoch 123/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 9.6109e-05 - val_loss: 7.3786e-04
#
# Epoch 00123: val_loss did not improve from 0.00069
# Epoch 124/150
# 1712/1712 [==============================] - 1s 464us/step - loss: 9.9454e-05 - val_loss: 7.2562e-04
#
# Epoch 00124: val_loss did not improve from 0.00069
# Epoch 125/150
# 1712/1712 [==============================] - 1s 461us/step - loss: 1.0036e-04 - val_loss: 7.3006e-04
#
# Epoch 00125: val_loss did not improve from 0.00069
# Epoch 126/150
# 1712/1712 [==============================] - 1s 462us/step - loss: 9.5704e-05 - val_loss: 7.6130e-04
#
# Epoch 00126: val_loss did not improve from 0.00069
# Epoch 127/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 9.9326e-05 - val_loss: 7.8752e-04
#
# Epoch 00127: val_loss did not improve from 0.00069
# Epoch 128/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 9.6865e-05 - val_loss: 7.4652e-04
#
# Epoch 00128: val_loss did not improve from 0.00069
# Epoch 129/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.4107e-05 - val_loss: 7.3077e-04
#
# Epoch 00129: val_loss did not improve from 0.00069
# Epoch 130/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 9.3975e-05 - val_loss: 7.3464e-04
#
# Epoch 00130: val_loss did not improve from 0.00069
# Epoch 131/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 8.9672e-05 - val_loss: 7.6360e-04
#
# Epoch 00131: val_loss did not improve from 0.00069
# Epoch 132/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 9.0077e-05 - val_loss: 7.3674e-04
#
# Epoch 00132: val_loss did not improve from 0.00069
# Epoch 133/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 9.0961e-05 - val_loss: 7.4379e-04
#
# Epoch 00133: val_loss did not improve from 0.00069
# Epoch 134/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 9.0120e-05 - val_loss: 7.3633e-04
#
# Epoch 00134: val_loss did not improve from 0.00069
# Epoch 135/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 9.1494e-05 - val_loss: 7.6257e-04
#
# Epoch 00135: val_loss did not improve from 0.00069
# Epoch 136/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 9.1038e-05 - val_loss: 7.4858e-04
#
# Epoch 00136: val_loss did not improve from 0.00069
# Epoch 137/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 8.8899e-05 - val_loss: 7.6271e-04
#
# Epoch 00137: val_loss did not improve from 0.00069
# Epoch 138/150
# 1712/1712 [==============================] - 1s 459us/step - loss: 8.8664e-05 - val_loss: 7.3694e-04
#
# Epoch 00138: val_loss did not improve from 0.00069
# Epoch 139/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 8.8847e-05 - val_loss: 7.5114e-04
#
# Epoch 00139: val_loss did not improve from 0.00069
# Epoch 140/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 8.9904e-05 - val_loss: 7.2634e-04
#
# Epoch 00140: val_loss did not improve from 0.00069
# Epoch 141/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 8.7685e-05 - val_loss: 7.8872e-04
#
# Epoch 00141: val_loss did not improve from 0.00069
# Epoch 142/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 8.8828e-05 - val_loss: 7.7529e-04
#
# Epoch 00142: val_loss did not improve from 0.00069
# Epoch 143/150
# 1712/1712 [==============================] - 1s 458us/step - loss: 8.8521e-05 - val_loss: 7.4863e-04
#
# Epoch 00143: val_loss did not improve from 0.00069
# Epoch 144/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 8.8538e-05 - val_loss: 7.2730e-04
#
# Epoch 00144: val_loss did not improve from 0.00069
# Epoch 145/150
# 1712/1712 [==============================] - 1s 460us/step - loss: 8.7266e-05 - val_loss: 7.2815e-04
#
# Epoch 00145: val_loss did not improve from 0.00069
# Epoch 146/150
# 1712/1712 [==============================] - 1s 454us/step - loss: 9.0304e-05 - val_loss: 7.3422e-04
#
# Epoch 00146: val_loss did not improve from 0.00069
# Epoch 147/150
# 1712/1712 [==============================] - 1s 456us/step - loss: 8.8319e-05 - val_loss: 7.2935e-04
#
# Epoch 00147: val_loss did not improve from 0.00069
# Epoch 148/150
# 1712/1712 [==============================] - 1s 453us/step - loss: 8.5717e-05 - val_loss: 7.6045e-04
#
# Epoch 00148: val_loss did not improve from 0.00069
# Epoch 149/150
# 1712/1712 [==============================] - 1s 457us/step - loss: 8.7375e-05 - val_loss: 7.4382e-04
#
# Epoch 00149: val_loss did not improve from 0.00069
# Epoch 150/150
# 1712/1712 [==============================] - 1s 455us/step - loss: 8.7434e-05 - val_loss: 7.6330e-04
#
# Epoch 00150: val_loss did not improve from 0.00069

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
def augment_data(img, points):
    rows, cols = img.shape
    # np.copy(img)複製圖片
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    # np.copy(points):複製關鍵點
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

# 製作空白的figure來製作圖中圖
fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[]) #xticks=[]:x軸刻度、yticks=[]:y軸刻度
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[]) #xticks=[]:x軸刻度、yticks=[]:y軸刻度
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True) #按固定間隔，存儲模型，預設是每個epoch存儲一次模型
# training the model
# 進行訓練, 訓練過程會存在 hist_model_aug 變數中
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), # 輸入數據 
                                        aug_points_train,  # 標籤
                                        validation_split=0.2, # 用來指定訓練集的一定比例數據作為驗證集
                                        batch_size=64, # 指定進行梯度下降時每個batch包含的樣本數。
                                        callbacks=[checkpoint_aug, hist],
                                        shuffle=True, #表示是否在訓練過程中每個epoch前隨機打亂輸入樣本的順序
                                        epochs=150, #訓練終止時的epoch值，訓練將在達到該epoch值時停止，
                                        verbose=1) #日誌顯示，0為不在標準輸出流輸出日誌信息，1為輸出進度條記錄，2為每個epoch輸出一行記錄
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 2s 562us/step - loss: 0.0041 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00189, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00189 to 0.00187, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 0.0010 - val_loss: 0.0017
#
# Epoch 00003: val_loss improved from 0.00187 to 0.00169, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 7.9801e-04 - val_loss: 0.0014
#
# Epoch 00004: val_loss improved from 0.00169 to 0.00137, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 6.2935e-04 - val_loss: 0.0011
#
# Epoch 00005: val_loss improved from 0.00137 to 0.00112, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 5.2390e-04 - val_loss: 0.0010
#
# Epoch 00006: val_loss improved from 0.00112 to 0.00102, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 4.6460e-04 - val_loss: 9.5177e-04
#
# Epoch 00007: val_loss improved from 0.00102 to 0.00095, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 4.3569e-04 - val_loss: 8.7130e-04
#
# Epoch 00008: val_loss improved from 0.00095 to 0.00087, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 3.9692e-04 - val_loss: 8.7754e-04
#
# Epoch 00009: val_loss did not improve from 0.00087
# Epoch 10/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 3.6943e-04 - val_loss: 8.5293e-04
#
# Epoch 00010: val_loss improved from 0.00087 to 0.00085, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 3.4901e-04 - val_loss: 8.1341e-04
#
# Epoch 00011: val_loss improved from 0.00085 to 0.00081, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 3.3649e-04 - val_loss: 7.9438e-04
#
# Epoch 00012: val_loss improved from 0.00081 to 0.00079, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 3.1582e-04 - val_loss: 7.3326e-04
#
# Epoch 00013: val_loss improved from 0.00079 to 0.00073, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 2.9861e-04 - val_loss: 7.4120e-04
#
# Epoch 00014: val_loss did not improve from 0.00073
# Epoch 15/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 2.8569e-04 - val_loss: 7.2005e-04
#
# Epoch 00015: val_loss improved from 0.00073 to 0.00072, saving model to best_weights_augment.h5
# Epoch 16/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 2.8501e-04 - val_loss: 7.2330e-04
#
# Epoch 00016: val_loss did not improve from 0.00072
# Epoch 17/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 2.7430e-04 - val_loss: 7.0294e-04
#
# Epoch 00017: val_loss improved from 0.00072 to 0.00070, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 2.6521e-04 - val_loss: 7.1424e-04
#
# Epoch 00018: val_loss did not improve from 0.00070
# Epoch 19/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 2.5789e-04 - val_loss: 7.1111e-04
#
# Epoch 00019: val_loss did not improve from 0.00070
# Epoch 20/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 2.4251e-04 - val_loss: 7.1776e-04
#
# Epoch 00020: val_loss did not improve from 0.00070
# Epoch 21/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 2.3427e-04 - val_loss: 7.1914e-04
#
# Epoch 00021: val_loss did not improve from 0.00070
# Epoch 22/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 2.3043e-04 - val_loss: 6.7722e-04
#
# Epoch 00022: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 2.2840e-04 - val_loss: 6.6249e-04
#
# Epoch 00023: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 2.1405e-04 - val_loss: 6.8721e-04
#
# Epoch 00024: val_loss did not improve from 0.00066
# Epoch 25/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 2.1321e-04 - val_loss: 6.8290e-04
#
# Epoch 00025: val_loss did not improve from 0.00066
# Epoch 26/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 2.0686e-04 - val_loss: 6.7616e-04
#
# Epoch 00026: val_loss did not improve from 0.00066
# Epoch 27/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 2.0701e-04 - val_loss: 6.6794e-04
#
# Epoch 00027: val_loss did not improve from 0.00066
# Epoch 28/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 2.0596e-04 - val_loss: 6.9652e-04
#
# Epoch 00028: val_loss did not improve from 0.00066
# Epoch 29/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 1.9847e-04 - val_loss: 6.4555e-04
#
# Epoch 00029: val_loss improved from 0.00066 to 0.00065, saving model to best_weights_augment.h5
# Epoch 30/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.9248e-04 - val_loss: 6.5554e-04
#
# Epoch 00030: val_loss did not improve from 0.00065
# Epoch 31/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.9387e-04 - val_loss: 6.3496e-04
#
# Epoch 00031: val_loss improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 32/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.8723e-04 - val_loss: 6.5819e-04
#
# Epoch 00032: val_loss did not improve from 0.00063
# Epoch 33/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.8184e-04 - val_loss: 6.7242e-04
#
# Epoch 00033: val_loss did not improve from 0.00063
# Epoch 34/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.7646e-04 - val_loss: 6.6538e-04
#
# Epoch 00034: val_loss did not improve from 0.00063
# Epoch 35/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.7597e-04 - val_loss: 6.5958e-04
#
# Epoch 00035: val_loss did not improve from 0.00063
# Epoch 36/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.7404e-04 - val_loss: 6.4530e-04
#
# Epoch 00036: val_loss did not improve from 0.00063
# Epoch 37/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.6499e-04 - val_loss: 6.5711e-04
#
# Epoch 00037: val_loss did not improve from 0.00063
# Epoch 38/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 1.6772e-04 - val_loss: 6.3296e-04
#
# Epoch 00038: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 39/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.6623e-04 - val_loss: 6.3414e-04
#
# Epoch 00039: val_loss did not improve from 0.00063
# Epoch 40/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.6088e-04 - val_loss: 6.2759e-04
#
# Epoch 00040: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 41/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.5553e-04 - val_loss: 6.4044e-04
#
# Epoch 00041: val_loss did not improve from 0.00063
# Epoch 42/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.5387e-04 - val_loss: 6.5379e-04
#
# Epoch 00042: val_loss did not improve from 0.00063
# Epoch 43/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 1.5196e-04 - val_loss: 6.6204e-04
#
# Epoch 00043: val_loss did not improve from 0.00063
# Epoch 44/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.4905e-04 - val_loss: 6.4800e-04
#
# Epoch 00044: val_loss did not improve from 0.00063
# Epoch 45/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 1.4867e-04 - val_loss: 6.4329e-04
#
# Epoch 00045: val_loss did not improve from 0.00063
# Epoch 46/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.4608e-04 - val_loss: 6.5578e-04
#
# Epoch 00046: val_loss did not improve from 0.00063
# Epoch 47/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.4397e-04 - val_loss: 6.6447e-04
#
# Epoch 00047: val_loss did not improve from 0.00063
# Epoch 48/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.4377e-04 - val_loss: 6.7711e-04
#
# Epoch 00048: val_loss did not improve from 0.00063
# Epoch 49/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.4022e-04 - val_loss: 6.3776e-04
#
# Epoch 00049: val_loss did not improve from 0.00063
# Epoch 50/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.3789e-04 - val_loss: 6.7000e-04
#
# Epoch 00050: val_loss did not improve from 0.00063
# Epoch 51/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.3813e-04 - val_loss: 6.6892e-04
#
# Epoch 00051: val_loss did not improve from 0.00063
# Epoch 52/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.3780e-04 - val_loss: 6.1962e-04
#
# Epoch 00052: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 53/150
# 3424/3424 [==============================] - 2s 468us/step - loss: 1.3483e-04 - val_loss: 6.5921e-04
#
# Epoch 00053: val_loss did not improve from 0.00062
# Epoch 54/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.3251e-04 - val_loss: 6.3814e-04
#
# Epoch 00054: val_loss did not improve from 0.00062
# Epoch 55/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 1.2946e-04 - val_loss: 6.3358e-04
#
# Epoch 00055: val_loss did not improve from 0.00062
# Epoch 56/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 1.2851e-04 - val_loss: 6.3182e-04
#
# Epoch 00056: val_loss did not improve from 0.00062
# Epoch 57/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.2770e-04 - val_loss: 6.2170e-04
#
# Epoch 00057: val_loss did not improve from 0.00062
# Epoch 58/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.2686e-04 - val_loss: 6.4758e-04
#
# Epoch 00058: val_loss did not improve from 0.00062
# Epoch 59/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.2573e-04 - val_loss: 6.1812e-04
#
# Epoch 00059: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 60/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 1.2345e-04 - val_loss: 6.2608e-04
#
# Epoch 00060: val_loss did not improve from 0.00062
# Epoch 61/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 1.2053e-04 - val_loss: 6.6068e-04
#
# Epoch 00061: val_loss did not improve from 0.00062
# Epoch 62/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.2134e-04 - val_loss: 6.4800e-04
#
# Epoch 00062: val_loss did not improve from 0.00062
# Epoch 63/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.2085e-04 - val_loss: 6.5033e-04
#
# Epoch 00063: val_loss did not improve from 0.00062
# Epoch 64/150
# 3424/3424 [==============================] - 2s 464us/step - loss: 1.1684e-04 - val_loss: 6.3499e-04
#
# Epoch 00064: val_loss did not improve from 0.00062
# Epoch 65/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.1738e-04 - val_loss: 6.4813e-04
#
# Epoch 00065: val_loss did not improve from 0.00062
# Epoch 66/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.1691e-04 - val_loss: 6.1683e-04
#
# Epoch 00066: val_loss improved from 0.00062 to 0.00062, saving model to best_weights_augment.h5
# Epoch 67/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 1.1616e-04 - val_loss: 5.9506e-04
#
# Epoch 00067: val_loss improved from 0.00062 to 0.00060, saving model to best_weights_augment.h5
# Epoch 68/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.1554e-04 - val_loss: 6.2894e-04
#
# Epoch 00068: val_loss did not improve from 0.00060
# Epoch 69/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.1618e-04 - val_loss: 6.4371e-04
#
# Epoch 00069: val_loss did not improve from 0.00060
# Epoch 70/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.1799e-04 - val_loss: 6.1325e-04
#
# Epoch 00070: val_loss did not improve from 0.00060
# Epoch 71/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 1.1550e-04 - val_loss: 6.3202e-04
#
# Epoch 00071: val_loss did not improve from 0.00060
# Epoch 72/150
# 3424/3424 [==============================] - 2s 463us/step - loss: 1.0888e-04 - val_loss: 6.5924e-04
#
# Epoch 00072: val_loss did not improve from 0.00060
# Epoch 73/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.0610e-04 - val_loss: 6.5004e-04
#
# Epoch 00073: val_loss did not improve from 0.00060
# Epoch 74/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 1.0536e-04 - val_loss: 6.6070e-04
#
# Epoch 00074: val_loss did not improve from 0.00060
# Epoch 75/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 1.0660e-04 - val_loss: 6.6589e-04
#
# Epoch 00075: val_loss did not improve from 0.00060
# Epoch 76/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.0679e-04 - val_loss: 6.3793e-04
#
# Epoch 00076: val_loss did not improve from 0.00060
# Epoch 77/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.0648e-04 - val_loss: 6.5175e-04
#
# Epoch 00077: val_loss did not improve from 0.00060
# Epoch 78/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.0460e-04 - val_loss: 6.5142e-04
#
# Epoch 00078: val_loss did not improve from 0.00060
# Epoch 79/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.0319e-04 - val_loss: 6.0997e-04
#
# Epoch 00079: val_loss did not improve from 0.00060
# Epoch 80/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 1.0083e-04 - val_loss: 6.1143e-04
#
# Epoch 00080: val_loss did not improve from 0.00060
# Epoch 81/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 1.0420e-04 - val_loss: 6.3033e-04
#
# Epoch 00081: val_loss did not improve from 0.00060
# Epoch 82/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.0278e-04 - val_loss: 6.3473e-04
#
# Epoch 00082: val_loss did not improve from 0.00060
# Epoch 83/150
# 3424/3424 [==============================] - 2s 458us/step - loss: 1.0033e-04 - val_loss: 6.4951e-04
#
# Epoch 00083: val_loss did not improve from 0.00060
# Epoch 84/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 1.0432e-04 - val_loss: 6.3018e-04
#
# Epoch 00084: val_loss did not improve from 0.00060
# Epoch 85/150
# 3424/3424 [==============================] - 2s 476us/step - loss: 1.0066e-04 - val_loss: 6.2651e-04
#
# Epoch 00085: val_loss did not improve from 0.00060
# Epoch 86/150
# 3424/3424 [==============================] - 2s 466us/step - loss: 9.9081e-05 - val_loss: 6.4756e-04
#
# Epoch 00086: val_loss did not improve from 0.00060
# Epoch 87/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 1.0082e-04 - val_loss: 6.3269e-04
#
# Epoch 00087: val_loss did not improve from 0.00060
# Epoch 88/150
# 3424/3424 [==============================] - 2s 462us/step - loss: 9.9637e-05 - val_loss: 6.1446e-04
#
# Epoch 00088: val_loss did not improve from 0.00060
# Epoch 89/150
# 3424/3424 [==============================] - 2s 476us/step - loss: 9.9077e-05 - val_loss: 6.3465e-04
#
# Epoch 00089: val_loss did not improve from 0.00060
# Epoch 90/150
# 3424/3424 [==============================] - 2s 490us/step - loss: 1.0207e-04 - val_loss: 6.4611e-04
#
# Epoch 00090: val_loss did not improve from 0.00060
# Epoch 91/150
# 3424/3424 [==============================] - 2s 484us/step - loss: 9.6515e-05 - val_loss: 6.3644e-04
#
# Epoch 00091: val_loss did not improve from 0.00060
# Epoch 92/150
# 3424/3424 [==============================] - 2s 465us/step - loss: 9.4602e-05 - val_loss: 6.3126e-04
#
# Epoch 00092: val_loss did not improve from 0.00060
# Epoch 93/150
# 3424/3424 [==============================] - 2s 460us/step - loss: 9.5903e-05 - val_loss: 6.2394e-04
#
# Epoch 00093: val_loss did not improve from 0.00060
# Epoch 94/150
# 3424/3424 [==============================] - 2s 474us/step - loss: 9.4275e-05 - val_loss: 6.2479e-04
#
# Epoch 00094: val_loss did not improve from 0.00060
# Epoch 95/150
# 3424/3424 [==============================] - 2s 478us/step - loss: 9.3659e-05 - val_loss: 6.3410e-04
#
# Epoch 00095: val_loss did not improve from 0.00060
# Epoch 96/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 9.2838e-05 - val_loss: 6.3893e-04
#
# Epoch 00096: val_loss did not improve from 0.00060
# Epoch 97/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 9.4134e-05 - val_loss: 6.3778e-04
#
# Epoch 00097: val_loss did not improve from 0.00060
# Epoch 98/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 9.2554e-05 - val_loss: 6.6817e-04
#
# Epoch 00098: val_loss did not improve from 0.00060
# Epoch 99/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 9.3153e-05 - val_loss: 6.3821e-04
#
# Epoch 00099: val_loss did not improve from 0.00060
# Epoch 100/150
# 3424/3424 [==============================] - 2s 453us/step - loss: 9.2218e-05 - val_loss: 6.2764e-04
#
# Epoch 00100: val_loss did not improve from 0.00060
# Epoch 101/150
# 3424/3424 [==============================] - 2s 451us/step - loss: 9.1883e-05 - val_loss: 6.2711e-04
#
# Epoch 00101: val_loss did not improve from 0.00060
# Epoch 102/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 9.1197e-05 - val_loss: 6.1679e-04
#
# Epoch 00102: val_loss did not improve from 0.00060
# Epoch 103/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 8.8868e-05 - val_loss: 6.5039e-04
#
# Epoch 00103: val_loss did not improve from 0.00060
# Epoch 104/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 8.9125e-05 - val_loss: 6.3687e-04
#
# Epoch 00104: val_loss did not improve from 0.00060
# Epoch 105/150
# 3424/3424 [==============================] - 2s 453us/step - loss: 9.0291e-05 - val_loss: 6.3724e-04
#
# Epoch 00105: val_loss did not improve from 0.00060
# Epoch 106/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 8.7194e-05 - val_loss: 6.2941e-04
#
# Epoch 00106: val_loss did not improve from 0.00060
# Epoch 107/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 8.5476e-05 - val_loss: 6.1410e-04
#
# Epoch 00107: val_loss did not improve from 0.00060
# Epoch 108/150
# 3424/3424 [==============================] - 2s 449us/step - loss: 8.7246e-05 - val_loss: 6.6280e-04
#
# Epoch 00108: val_loss did not improve from 0.00060
# Epoch 109/150
# 3424/3424 [==============================] - 2s 451us/step - loss: 8.7436e-05 - val_loss: 6.1885e-04
#
# Epoch 00109: val_loss did not improve from 0.00060
# Epoch 110/150
# 3424/3424 [==============================] - 2s 449us/step - loss: 8.9210e-05 - val_loss: 6.4477e-04
#
# Epoch 00110: val_loss did not improve from 0.00060
# Epoch 111/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 9.2735e-05 - val_loss: 6.5218e-04
#
# Epoch 00111: val_loss did not improve from 0.00060
# Epoch 112/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 8.6087e-05 - val_loss: 6.3028e-04
#
# Epoch 00112: val_loss did not improve from 0.00060
# Epoch 113/150
# 3424/3424 [==============================] - 2s 451us/step - loss: 8.7505e-05 - val_loss: 6.4445e-04
#
# Epoch 00113: val_loss did not improve from 0.00060
# Epoch 114/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 8.5564e-05 - val_loss: 6.3713e-04
#
# Epoch 00114: val_loss did not improve from 0.00060
# Epoch 115/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 8.5424e-05 - val_loss: 6.4215e-04
#
# Epoch 00115: val_loss did not improve from 0.00060
# Epoch 116/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 8.7059e-05 - val_loss: 6.3050e-04
#
# Epoch 00116: val_loss did not improve from 0.00060
# Epoch 117/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 8.6252e-05 - val_loss: 6.4151e-04
#
# Epoch 00117: val_loss did not improve from 0.00060
# Epoch 118/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 8.5549e-05 - val_loss: 6.3999e-04
#
# Epoch 00118: val_loss did not improve from 0.00060
# Epoch 119/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 8.2668e-05 - val_loss: 6.3469e-04
#
# Epoch 00119: val_loss did not improve from 0.00060
# Epoch 120/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 8.3330e-05 - val_loss: 6.3659e-04
#
# Epoch 00120: val_loss did not improve from 0.00060
# Epoch 121/150
# 3424/3424 [==============================] - 2s 453us/step - loss: 8.1540e-05 - val_loss: 6.2772e-04
#
# Epoch 00121: val_loss did not improve from 0.00060
# Epoch 122/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 8.1100e-05 - val_loss: 6.3047e-04
#
# Epoch 00122: val_loss did not improve from 0.00060
# Epoch 123/150
# 3424/3424 [==============================] - 2s 461us/step - loss: 8.0974e-05 - val_loss: 6.2300e-04
#
# Epoch 00123: val_loss did not improve from 0.00060
# Epoch 124/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 8.0888e-05 - val_loss: 6.3886e-04
#
# Epoch 00124: val_loss did not improve from 0.00060
# Epoch 125/150
# 3424/3424 [==============================] - 2s 449us/step - loss: 8.2322e-05 - val_loss: 6.3717e-04
#
# Epoch 00125: val_loss did not improve from 0.00060
# Epoch 126/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 8.3382e-05 - val_loss: 6.4654e-04
#
# Epoch 00126: val_loss did not improve from 0.00060
# Epoch 127/150
# 3424/3424 [==============================] - 2s 449us/step - loss: 8.3934e-05 - val_loss: 6.4787e-04
#
# Epoch 00127: val_loss did not improve from 0.00060
# Epoch 128/150
# 3424/3424 [==============================] - 2s 449us/step - loss: 8.2497e-05 - val_loss: 6.4620e-04
#
# Epoch 00128: val_loss did not improve from 0.00060
# Epoch 129/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 8.2017e-05 - val_loss: 6.2164e-04
#
# Epoch 00129: val_loss did not improve from 0.00060
# Epoch 130/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 8.4042e-05 - val_loss: 6.4187e-04
#
# Epoch 00130: val_loss did not improve from 0.00060
# Epoch 131/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 8.3515e-05 - val_loss: 6.3628e-04
#
# Epoch 00131: val_loss did not improve from 0.00060
# Epoch 132/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 8.0868e-05 - val_loss: 6.4287e-04
#
# Epoch 00132: val_loss did not improve from 0.00060
# Epoch 133/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 8.0454e-05 - val_loss: 6.3202e-04
#
# Epoch 00133: val_loss did not improve from 0.00060
# Epoch 134/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 8.0241e-05 - val_loss: 6.2050e-04
#
# Epoch 00134: val_loss did not improve from 0.00060
# Epoch 135/150
# 3424/3424 [==============================] - 2s 472us/step - loss: 7.8661e-05 - val_loss: 6.2223e-04
#
# Epoch 00135: val_loss did not improve from 0.00060
# Epoch 136/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 7.9192e-05 - val_loss: 6.0553e-04
#
# Epoch 00136: val_loss did not improve from 0.00060
# Epoch 137/150
# 3424/3424 [==============================] - 2s 454us/step - loss: 7.8547e-05 - val_loss: 6.1877e-04
#
# Epoch 00137: val_loss did not improve from 0.00060
# Epoch 138/150
# 3424/3424 [==============================] - 2s 452us/step - loss: 7.7263e-05 - val_loss: 6.4380e-04
#
# Epoch 00138: val_loss did not improve from 0.00060
# Epoch 139/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.8778e-05 - val_loss: 6.3670e-04
#
# Epoch 00139: val_loss did not improve from 0.00060
# Epoch 140/150
# 3424/3424 [==============================] - 2s 453us/step - loss: 8.0381e-05 - val_loss: 6.5623e-04
#
# Epoch 00140: val_loss did not improve from 0.00060
# Epoch 141/150
# 3424/3424 [==============================] - 2s 459us/step - loss: 7.9724e-05 - val_loss: 6.3146e-04
#
# Epoch 00141: val_loss did not improve from 0.00060
# Epoch 142/150
# 3424/3424 [==============================] - 2s 457us/step - loss: 7.7544e-05 - val_loss: 6.2719e-04
#
# Epoch 00142: val_loss did not improve from 0.00060
# Epoch 143/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 8.0371e-05 - val_loss: 6.2499e-04
#
# Epoch 00143: val_loss did not improve from 0.00060
# Epoch 144/150
# 3424/3424 [==============================] - 2s 450us/step - loss: 7.7451e-05 - val_loss: 6.3853e-04
#
# Epoch 00144: val_loss did not improve from 0.00060
# Epoch 145/150
# 3424/3424 [==============================] - 2s 455us/step - loss: 7.6533e-05 - val_loss: 6.2178e-04
#
# Epoch 00145: val_loss did not improve from 0.00060
# Epoch 146/150
# 3424/3424 [==============================] - 2s 456us/step - loss: 7.7379e-05 - val_loss: 6.3494e-04
#
# Epoch 00146: val_loss did not improve from 0.00060
# Epoch 147/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 7.8656e-05 - val_loss: 6.3112e-04
#
# Epoch 00147: val_loss did not improve from 0.00060
# Epoch 148/150
# 3424/3424 [==============================] - 2s 467us/step - loss: 7.6856e-05 - val_loss: 6.1945e-04
#
# Epoch 00148: val_loss did not improve from 0.00060
# Epoch 149/150
# 3424/3424 [==============================] - 2s 471us/step - loss: 8.0059e-05 - val_loss: 6.3929e-04
#
# Epoch 00149: val_loss did not improve from 0.00060
# Epoch 150/150
# 3424/3424 [==============================] - 2s 469us/step - loss: 7.7187e-05 - val_loss: 6.3756e-04
#
# Epoch 00150: val_loss did not improve from 0.00060

# %% [markdown]
# ### Graph Plots

# %%
# loss 值的圖
# loss plot ( 繪製訓練 & 驗證的損失值)
plt.figure(figsize=(16,5))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist.history['loss'], color='b', label='Training Loss')
plt.plot(hist.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# accuracy plot(繪製訓練 & 驗證的準確率值)
#plt.subplot(1, 2, 2)
#plt.ylabel('Accuracy', fontsize=16)
#plt.plot(hist.history['accuracy'], color='b', label='Training Accuracy')
#plt.plot(hist.history['val_accurcay'], color='r', label='Validation Accuracy')
#plt.legend(loc='lower right')
#plt.show()

# %% [markdown]
# ### 訓練歷史可視化

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %%
from keras.utils.vis_utils import plot_model
import os
#plot_model 模型可視化
plot_model(model, 
           to_file='model_plot.png', 
           show_shapes=True,  # 指定是否顯示輸出數據的形狀
           show_layer_names=True) # 指定是否顯示層名稱
